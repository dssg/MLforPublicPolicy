# %% [markdown]
# # Lab 6: Clustering
# In this lab we'll try to get a better sense of all the clustering algorithms discussed in class. One of the many reasons to cluster is that it can help us better visualize and understand our data. To that end, we'll also get some more practice with data visualization techniques that may be helpful for your projects and future data analysis.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# We'll begin by messing around the Iris dataset, which is a fairly easy, small 3-way classification dataset. The dataset consists of 150 irises that each fall into one of 3 classes(Setosa, Versicolour, and Virginica). Each iris comes with 4 features: sepal length, sepal width, petal length, and petal width.

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
X = data.data
y = data.target

# %%
print(data.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# To get a better sense of the distributions of the data. Let's first plot histograms of each of the four features:

# %%
# YOUR CODE HERE

# %% [markdown]
# From the names of the features, it probably makes most sense to scatter the sepal length vs the sepal width and the petal length vs petal width. Use plt.scatter to visualize the data.

# %%
# Make a dataframe out of the data to make it easier to do filtering/grouping operations later
col_names = ['sep_len', 'sep_wid', 'pet_len', 'pet_wid']
df = pd.DataFrame(data.data)

df.rename(columns=lambda x: col_names[x], inplace=True)
df['target'] = data.target

# %%
# Scatter the sep_len vs sep_wid
# YOUR CODE HERE
# This is what the scatter plot should look like:

# %%
# Scatter the pet_len vs pet_wid
# YOUR CODE HERE
# This is what the scatter plot should look like:

# %% [markdown]
# It may be hard to see anything interesting from just monochromatic scatter plots. Let's color in the datapoints according to their class. Hint: try grouping by the target value and then do plt.scatter on each group with different colors.

# %%
# Write a function to plot a scatter plot of the dataframe that color codes each point
# according to its true class.
# YOUR CODE HERE

# %%
# This is what the output should look like:

# %% [markdown]
# From the plots, its clear that we can easily cluster the data into 3 clusters. Let's see if KMeans and Meanshift can recover these clusters.

# %% [markdown]
# ## KMeans
# Run KMeans with n_clusters = 2, 3, 4 plot a color coded(according to the cluster value) scatter plot for petal length vs petal width(or any two features of your choice).

# %%
from sklearn.cluster import KMeans, MeanShift, SpectralClustering
# YOUR CODE HERE

# %%
# Here's what the plots should look like:

# %% [markdown]
# ## MeanShift
# Use MeanShift to cluster the data points. Remember that the bandwidth parameter of MeanShift determines how much to weigh the neighbors of each point when cluster centroids are recomputed. Vary the bandwidth parameter from very low to very high and see how the clustering changes. As with KMeans, plot a color coded scatter plot for the optimal bandwidths. By optimal we mean bandwidth values that give a sensible number(between 2 and 5) of clusters.

# %%
# YOUR CODE HERE

# %%
# Here's what some of the plots look like for various bandwidth values:

# %% [markdown]
# As you can see from these plots and from your own experiments, the bandwidth parameter can be extremely sensitive and thus needs to be tuned carefully to give any meaningful results.
